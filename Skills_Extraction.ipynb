# %% [markdown]
# <a href="https://colab.research.google.com/github/saniya1027108/Skills-Extraction-From-Resume/blob/main/Skills_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install resume_parser
! pip install nltk
! pip install spacy==2.3.5
! pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
! pip install pyresparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 26.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 91.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 KB 4.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 79.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 100.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.6/143.6 KB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 99.5 MB/s eta 0:00:00
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=3a3caca27a462d43fb311a04c5b99555c73c5e3c0e18ab6caeee4751d813d7fc
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pyresparser import ResumeParser #Library 2
import os
import spacy

# %%
from google.colab import drive

# %%
dir_list = os.listdir(r'/content/drive/MyDrive/Role Categories/Hr and training')
#print(dir_list)

res_list = []
res_list1 = []
paths = r'/content/drive/MyDrive/Role Categories/Hr and training'
c = 0
for i in dir_list:
    c = c + 1
    if c == 5000:
        break
    pfinal = os.path.join(paths, i)
    data = ResumeParser(pfinal).get_extracted_data()
    res_list.append(data)

    pdfReader = PdfReader(pfinal)
    pageObj = pdfReader.pages[0]
    data1 = pageObj.extract_text()
    res_list1.append(data1)
# Out:
# /usr/local/lib/python3.8/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# WARNING:PyPDF2._reader:Previous trailer can not be read ("'NumberObject' object is not subscriptable",)
# WARNING:PyPDF2._reader:Object ID 11,0 ref repaired
# WARNING:PyPDF2._reader:Object 8 0 found
# WARNING:PyPDF2._reader:Object ID 13,0 ref repaired
# WARNING:PyPDF2._reader:Object 1 0 found
# WARNING:PyPDF2._reader:Object 4 0 found
# WARNING:PyPDF2._reader:Object ID 14,0 ref repaired
# WARNING:PyPDF2._reader:Object ID 24,0 ref repaired
# WARNING:PyPDF2._reader:Object ID 28,0 ref repaired
# ...

# %%
import pandas as pd
df = pd.DataFrame(res_list)
df['resume_string']= ''
df['resume_string']= res_list1
df
# Out:
#                                name                               email  \
# 0                  Commander Anurag          cdr.anuragsaxena@gmail.com
# 1                        WAFI ASGAR                 wafiasgar@gmail.com
# 2                      Mandar Sathe            mandar.sathe33@gmail.com
# 3                  Ujjwal Divakaran         ujjwaldivakaran@hotmail.com
# 4                  Tejbhushan Joshi              j.tejas@rediffmail.com
# 5                              None                                None
# 6                  KAPIL SRIVASTAVA         kapilsrivastava@hotmail.com
# 7                  SAJITHA THIYYARA               sajithaster@gmail.com
# 8                       RAVI SHARMA              ravi30sharma@gmail.com
# 9                       HR Strategy                  sayush23@gmail.com
# 10                    Sheena Jacobi            sheenajacobi@hotmail.com
# 11                       EKTA KATTA              ID:ektakatta@gmail.com
# ...

# %%
! pip install PyPDF2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 KB 15.5 MB/s eta 0:00:00
# ...

# %%
import PyPDF2
import os
import pandas as pd
from PyPDF2 import PdfReader

# %%
df.to_csv('hr1.csv')
# !cp hr1.csv "drive/My Drive/"

# %%
from google.colab import files
files.download("w.csv")
